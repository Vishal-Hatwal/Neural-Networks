# %%
# Importing the necessary packages
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("C:\\Users\\DELL\\Downloads\\gas_turbines.csv")
data
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
data[data.duplicated()].shape
# Out:
# (0, 11)

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'AT'}>,
#         <AxesSubplot:title={'center':'AP'}>,
#         <AxesSubplot:title={'center':'AH'}>],
#        [<AxesSubplot:title={'center':'AFDP'}>,
#         <AxesSubplot:title={'center':'GTEP'}>,
#         <AxesSubplot:title={'center':'TIT'}>],
#        [<AxesSubplot:title={'center':'TAT'}>,
#         <AxesSubplot:title={'center':'TEY'}>,
#         <AxesSubplot:title={'center':'CDP'}>],
#        [<AxesSubplot:title={'center':'CO'}>,
#         <AxesSubplot:title={'center':'NOX'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
x = data.drop(labels = 'TEY', axis = 1)
y = data[['TEY']]

# %%
x
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  10.400  4.5186
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  10.433  4.8470
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  10.483  7.9632
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  10.533  6.2494
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  10.583  4.9816
#
#           NOX
# 0      82.722
# 1      82.776
# 2      82.468
# 3      82.670
# 4      82.311
# ...       ...
# 15034  79.559
# 15035  79.917
# 15036  90.912
# 15037  93.227
# 15038  92.498
#
# [15039 rows x 10 columns]

# %%
y
# Out:
#           TEY
# 0      114.70
# 1      114.72
# 2      114.71
# 3      114.72
# 4      114.72
# ...       ...
# 15034  111.61
# 15035  111.78
# 15036  110.19
# 15037  110.74
# 15038  111.58
#
# [15039 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
#converting into standard form.
sclar = MinMaxScaler()
scale_data = sclar.fit_transform(x)
scale_data
# Out:
# array([[0.18418215, 0.45604964, 0.95131413, ..., 0.1353398 , 0.07152212,
#         0.59654817],
#        [0.18201978, 0.4663909 , 0.95588067, ..., 0.13398756, 0.07337235,
#         0.59713433],
#        [0.18529531, 0.47466391, 0.93900309, ..., 0.13456709, 0.07257648,
#         0.59379104],
#        ...,
#        [0.19596183, 0.4229576 , 0.98992213, ..., 0.11177221, 0.18055195,
#         0.68544912],
#        [0.18844295, 0.43329886, 0.98293633, ..., 0.12143106, 0.14169257,
#         0.71057802],
#        [0.18617304, 0.44157187, 0.96182146, ..., 0.1310899 , 0.11294597,
#         0.70266486]])

# %%
x_train,x_test,y_train,y_test = train_test_split(scale_data,y,test_size = 0.30,random_state = 12)

# %% [markdown]
# # Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam,RMSprop

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=10, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='relu'))
    
    adam=Adam(learning_rate=0.01)
    model.compile(loss='mean_squared_error', optimizer=adam, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(x_train,y_train)
# Out:
# <ipython-input-18-b84a416b9735>:2: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 1/5; 1/9] END ..................batch_size=10, epochs=10; total time=  26.4s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 2/5; 1/9] END ..................batch_size=10, epochs=10; total time=  12.9s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 3/5; 1/9] END ..................batch_size=10, epochs=10; total time=  12.8s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 4/5; 1/9] END ..................batch_size=10, epochs=10; total time=  12.7s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 5/5; 1/9] END ..................batch_size=10, epochs=10; total time=  13.0s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 1/5; 2/9] END ..................batch_size=10, epochs=50; total time=  59.6s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 2/5; 2/9] END ..................batch_size=10, epochs=50; total time=  59.9s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 3/5; 2/9] END ..................batch_size=10, epochs=50; total time= 1.0min
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 4/5; 2/9] END ..................batch_size=10, epochs=50; total time= 1.0min
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 5/5; 2/9] END ..................batch_size=10, epochs=50; total time=  59.4s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 1/5; 3/9] END .................batch_size=10, epochs=100; total time= 2.0min
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 2/5; 3/9] END .................batch_size=10, epochs=100; total time= 2.0min
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 3/5; 3/9] END .................batch_size=10, epochs=100; total time= 2.0min
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 4/5; 3/9] END .................batch_size=10, epochs=100; total time= 2.0min
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 5/5; 3/9] END .................batch_size=10, epochs=100; total time= 2.0min
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 1/5; 4/9] END ..................batch_size=20, epochs=10; total time=   6.8s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 2/5; 4/9] END ..................batch_size=20, epochs=10; total time=   7.1s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 3/5; 4/9] END ..................batch_size=20, epochs=10; total time=   6.9s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 4/5; 4/9] END ..................batch_size=20, epochs=10; total time=   6.9s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 5/5; 4/9] END ..................batch_size=20, epochs=10; total time=   6.8s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 1/5; 5/9] END ..................batch_size=20, epochs=50; total time=  30.7s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 2/5; 5/9] END ..................batch_size=20, epochs=50; total time=  30.2s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 3/5; 5/9] END ..................batch_size=20, epochs=50; total time=  30.1s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 4/5; 5/9] END ..................batch_size=20, epochs=50; total time=  30.7s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 5/5; 5/9] END ..................batch_size=20, epochs=50; total time=  30.4s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 1/5; 6/9] END .................batch_size=20, epochs=100; total time= 1.0min
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 2/5; 6/9] END .................batch_size=20, epochs=100; total time= 1.0min
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 3/5; 6/9] END .................batch_size=20, epochs=100; total time= 1.0min
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 4/5; 6/9] END .................batch_size=20, epochs=100; total time= 1.0min
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 5/5; 6/9] END .................batch_size=20, epochs=100; total time= 1.0min
# [CV 1/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 1/5; 7/9] END ..................batch_size=40, epochs=10; total time=   3.8s
# [CV 2/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 2/5; 7/9] END ..................batch_size=40, epochs=10; total time=   3.8s
# [CV 3/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 3/5; 7/9] END ..................batch_size=40, epochs=10; total time=   3.9s
# [CV 4/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 4/5; 7/9] END ..................batch_size=40, epochs=10; total time=   3.8s
# [CV 5/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 5/5; 7/9] END ..................batch_size=40, epochs=10; total time=   3.9s
# [CV 1/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 1/5; 8/9] END ..................batch_size=40, epochs=50; total time=  15.9s
# [CV 2/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 2/5; 8/9] END ..................batch_size=40, epochs=50; total time=  16.1s
# [CV 3/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 3/5; 8/9] END ..................batch_size=40, epochs=50; total time=  15.7s
# [CV 4/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 4/5; 8/9] END ..................batch_size=40, epochs=50; total time=  15.7s
# [CV 5/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 5/5; 8/9] END ..................batch_size=40, epochs=50; total time=  17.3s
# [CV 1/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 1/5; 9/9] END .................batch_size=40, epochs=100; total time=  31.0s
# [CV 2/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 2/5; 9/9] END .................batch_size=40, epochs=100; total time=  30.6s
# [CV 3/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 3/5; 9/9] END .................batch_size=40, epochs=100; total time=  30.8s
# [CV 4/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 4/5; 9/9] END .................batch_size=40, epochs=100; total time=  30.6s
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 5/5; 9/9] END .................batch_size=40, epochs=100; total time=  31.2s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.00038000238710083066, using {'batch_size': 10, 'epochs': 50}
# 0.0002850356278941035,0.000570071255788207 with: {'batch_size': 10, 'epochs': 10}
# 0.00038000238710083066,0.0005540019480234182 with: {'batch_size': 10, 'epochs': 50}
# 0.00038000238710083066,0.0005540019480234182 with: {'batch_size': 10, 'epochs': 100}
# 0.00038000238710083066,0.0005540019480234182 with: {'batch_size': 20, 'epochs': 10}
# 0.0002850356278941035,0.000570071255788207 with: {'batch_size': 20, 'epochs': 50}
# 0.00038000238710083066,0.0005540019480234182 with: {'batch_size': 20, 'epochs': 100}
# 0.0002850356278941035,0.000570071255788207 with: {'batch_size': 40, 'epochs': 10}
# 0.00038000238710083066,0.0005540019480234182 with: {'batch_size': 40, 'epochs': 50}
# 0.00038000238710083066,0.0005540019480234182 with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# # Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model
def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 10,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'relu'))
    
    adam = Adam(learning_rate = learning_rate)
    model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters
param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(x_train,y_train)
# Out:
# <ipython-input-21-0d012d209e12>:3: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 1/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   4.0s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 2/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   3.9s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 3/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   3.9s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 4/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   3.8s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 5/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   4.2s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 1/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.8s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 2/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.8s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 3/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.9s
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 4/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.8s
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 5/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.9s
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 1/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.8s
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 2/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.8s
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 3/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.8s
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 4/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.8s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 5/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.8s
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 1/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   7.5s
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 2/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   4.5s
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 3/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   4.1s
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 4/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   4.2s
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 5/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   4.2s
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 1/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   4.1s
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 2/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   4.1s
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 3/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   4.1s
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 4/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   4.1s
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 5/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   4.1s
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 1/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   4.1s
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 2/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   4.1s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 3/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   4.5s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 4/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   4.3s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 5/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   4.2s
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 1/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   4.2s
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 2/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   4.1s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 3/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   4.2s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 4/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   4.1s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 5/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   4.2s
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 1/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   4.1s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 2/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   4.3s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 3/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   4.2s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 4/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   4.5s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 5/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   4.1s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 1/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   4.2s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 2/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   4.2s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 3/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   4.1s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 4/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   4.1s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 5/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   4.2s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.00038000238710083066, using {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.00018997863517142833,0.00023267537003559836 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.00038000238710083066,0.0005540019480234182 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 9.501187596470118e-05,0.0001900237519294024 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.0002850356278941035,0.000570071255788207 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.00038000238710083066,0.0005540019480234182 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.00038000238710083066,0.0005540019480234182 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.00038000238710083066,0.0005540019480234182 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.00038000238710083066,0.0005540019480234182 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.00038000238710083066,0.0005540019480234182 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# # Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 10,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 10,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'relu'))
    
    adam = Adam(learning_rate = 0.001)
    model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(x_train,y_train)
# Out:
# <ipython-input-24-06b2e48c346f>:2: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform; total time=   5.9s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform; total time=   4.6s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform; total time=   4.4s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform; total time=   4.8s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform; total time=   4.4s
# [CV 1/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 1/5; 2/12] END .activation_function=softmax, init=normal; total time=   4.4s
# [CV 2/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 2/5; 2/12] END .activation_function=softmax, init=normal; total time=   4.4s
# [CV 3/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 3/5; 2/12] END .activation_function=softmax, init=normal; total time=   4.4s
# [CV 4/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 4/5; 2/12] END .activation_function=softmax, init=normal; total time=   4.4s
# [CV 5/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 5/5; 2/12] END .activation_function=softmax, init=normal; total time=   4.4s
# [CV 1/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 1/5; 3/12] END ...activation_function=softmax, init=zero; total time=   4.4s
# [CV 2/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 2/5; 3/12] END ...activation_function=softmax, init=zero; total time=   4.4s
# [CV 3/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 3/5; 3/12] END ...activation_function=softmax, init=zero; total time=   4.4s
# [CV 4/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 4/5; 3/12] END ...activation_function=softmax, init=zero; total time=   4.4s
# [CV 5/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 5/5; 3/12] END ...activation_function=softmax, init=zero; total time=   4.8s
# [CV 1/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 1/5; 4/12] END ...activation_function=relu, init=uniform; total time=   4.1s
# [CV 2/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 2/5; 4/12] END ...activation_function=relu, init=uniform; total time=   4.2s
# [CV 3/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 3/5; 4/12] END ...activation_function=relu, init=uniform; total time=   4.3s
# [CV 4/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 4/5; 4/12] END ...activation_function=relu, init=uniform; total time=   4.2s
# [CV 5/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 5/5; 4/12] END ...activation_function=relu, init=uniform; total time=   4.2s
# [CV 1/5; 5/12] START activation_function=relu, init=normal......................
# [CV 1/5; 5/12] END ....activation_function=relu, init=normal; total time=   4.2s
# [CV 2/5; 5/12] START activation_function=relu, init=normal......................
# [CV 2/5; 5/12] END ....activation_function=relu, init=normal; total time=   4.2s
# [CV 3/5; 5/12] START activation_function=relu, init=normal......................
# [CV 3/5; 5/12] END ....activation_function=relu, init=normal; total time=   4.1s
# [CV 4/5; 5/12] START activation_function=relu, init=normal......................
# [CV 4/5; 5/12] END ....activation_function=relu, init=normal; total time=   4.3s
# [CV 5/5; 5/12] START activation_function=relu, init=normal......................
# [CV 5/5; 5/12] END ....activation_function=relu, init=normal; total time=   4.1s
# [CV 1/5; 6/12] START activation_function=relu, init=zero........................
# [CV 1/5; 6/12] END ......activation_function=relu, init=zero; total time=   4.5s
# [CV 2/5; 6/12] START activation_function=relu, init=zero........................
# [CV 2/5; 6/12] END ......activation_function=relu, init=zero; total time=   4.2s
# [CV 3/5; 6/12] START activation_function=relu, init=zero........................
# [CV 3/5; 6/12] END ......activation_function=relu, init=zero; total time=   4.2s
# [CV 4/5; 6/12] START activation_function=relu, init=zero........................
# [CV 4/5; 6/12] END ......activation_function=relu, init=zero; total time=   4.3s
# [CV 5/5; 6/12] START activation_function=relu, init=zero........................
# [CV 5/5; 6/12] END ......activation_function=relu, init=zero; total time=   4.2s
# [CV 1/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 1/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   5.6s
# [CV 2/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 2/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   4.2s
# [CV 3/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 3/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   4.2s
# [CV 4/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 4/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   4.2s
# [CV 5/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 5/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   4.2s
# [CV 1/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 1/5; 8/12] END ....activation_function=tanh, init=normal; total time=   4.3s
# [CV 2/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 2/5; 8/12] END ....activation_function=tanh, init=normal; total time=   4.2s
# [CV 3/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 3/5; 8/12] END ....activation_function=tanh, init=normal; total time=   4.5s
# [CV 4/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 4/5; 8/12] END ....activation_function=tanh, init=normal; total time=   4.2s
# [CV 5/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 5/5; 8/12] END ....activation_function=tanh, init=normal; total time=   4.1s
# [CV 1/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 1/5; 9/12] END ......activation_function=tanh, init=zero; total time=   4.1s
# [CV 2/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 2/5; 9/12] END ......activation_function=tanh, init=zero; total time=   4.1s
# [CV 3/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 3/5; 9/12] END ......activation_function=tanh, init=zero; total time=   4.2s
# [CV 4/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 4/5; 9/12] END ......activation_function=tanh, init=zero; total time=   4.2s
# [CV 5/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 5/5; 9/12] END ......activation_function=tanh, init=zero; total time=   4.2s
# [CV 1/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 1/5; 10/12] END activation_function=linear, init=uniform; total time=   4.1s
# [CV 2/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 2/5; 10/12] END activation_function=linear, init=uniform; total time=   4.1s
# [CV 3/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 3/5; 10/12] END activation_function=linear, init=uniform; total time=   4.1s
# [CV 4/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 4/5; 10/12] END activation_function=linear, init=uniform; total time=   4.5s
# [CV 5/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 5/5; 10/12] END activation_function=linear, init=uniform; total time=   4.1s
# [CV 1/5; 11/12] START activation_function=linear, init=normal...................
# [CV 1/5; 11/12] END .activation_function=linear, init=normal; total time=   4.2s
# [CV 2/5; 11/12] START activation_function=linear, init=normal...................
# [CV 2/5; 11/12] END .activation_function=linear, init=normal; total time=   4.3s
# [CV 3/5; 11/12] START activation_function=linear, init=normal...................
# [CV 3/5; 11/12] END .activation_function=linear, init=normal; total time=   4.1s
# [CV 4/5; 11/12] START activation_function=linear, init=normal...................
# [CV 4/5; 11/12] END .activation_function=linear, init=normal; total time=   4.1s
# [CV 5/5; 11/12] START activation_function=linear, init=normal...................
# [CV 5/5; 11/12] END .activation_function=linear, init=normal; total time=   4.5s
# [CV 1/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 1/5; 12/12] END ...activation_function=linear, init=zero; total time=   4.2s
# [CV 2/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 2/5; 12/12] END ...activation_function=linear, init=zero; total time=   4.4s
# [CV 3/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 3/5; 12/12] END ...activation_function=linear, init=zero; total time=   4.1s
# [CV 4/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 4/5; 12/12] END ...activation_function=linear, init=zero; total time=   4.4s
# [CV 5/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 5/5; 12/12] END ...activation_function=linear, init=zero; total time=   4.1s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.00038000238710083066, using {'activation_function': 'softmax', 'init': 'uniform'}
# 0.00038000238710083066,0.0005540019480234182 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 0.00038000238710083066,0.0005540019480234182 with: {'activation_function': 'softmax', 'init': 'normal'}
# 0.00038000238710083066,0.0005540019480234182 with: {'activation_function': 'softmax', 'init': 'zero'}
# 0.00038000238710083066,0.0005540019480234182 with: {'activation_function': 'relu', 'init': 'uniform'}
# 0.00038000238710083066,0.0005540019480234182 with: {'activation_function': 'relu', 'init': 'normal'}
# 9.501187596470118e-05,0.0001900237519294024 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.00038000238710083066,0.0005540019480234182 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.00038000238710083066,0.0005540019480234182 with: {'activation_function': 'tanh', 'init': 'normal'}
# 9.501187596470118e-05,0.0001900237519294024 with: {'activation_function': 'tanh', 'init': 'zero'}
# 0.00038000238710083066,0.0005540019480234182 with: {'activation_function': 'linear', 'init': 'uniform'}
# 0.00038000238710083066,0.0005540019480234182 with: {'activation_function': 'linear', 'init': 'normal'}
# 9.501187596470118e-05,0.0001900237519294024 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# # Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 10,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'relu'))
    
    adam = Adam(learning_rate = 0.001)
    model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters
param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(x_train,y_train)
# Out:
# <ipython-input-27-47a81517a0db>:2: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   4.2s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   4.2s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   4.2s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   4.1s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   4.3s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 1/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   4.1s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 2/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   4.2s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 3/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   4.2s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 4/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   4.5s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 5/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   4.1s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 1/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   4.2s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 2/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   4.2s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 3/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   4.2s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 4/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   4.1s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 5/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   4.2s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 1/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   4.2s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 2/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   4.2s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 3/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   4.1s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 4/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   4.1s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 5/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   4.2s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 1/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   4.6s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 2/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   4.2s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 3/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   4.1s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 4/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   4.2s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 5/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   4.1s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 1/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   4.2s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 2/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   4.2s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 3/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   4.2s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 4/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   4.5s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 5/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   4.4s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 1/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   4.4s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 2/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   4.6s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 3/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   4.3s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 4/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   4.2s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 5/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   4.2s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 1/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   4.2s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 2/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   4.2s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 3/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   4.2s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 4/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   4.2s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 5/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   4.2s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 1/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   4.2s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 2/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   4.2s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 3/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   4.6s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 4/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   4.3s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   4.3s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.00038000238710083066, using {'neuron1': 4, 'neuron2': 2}
# 0.00038000238710083066,0.0005540019480234182 with: {'neuron1': 4, 'neuron2': 2}
# 0.00038000238710083066,0.0005540019480234182 with: {'neuron1': 4, 'neuron2': 4}
# 0.00038000238710083066,0.0005540019480234182 with: {'neuron1': 4, 'neuron2': 8}
# 0.00038000238710083066,0.0005540019480234182 with: {'neuron1': 8, 'neuron2': 2}
# 0.00038000238710083066,0.0005540019480234182 with: {'neuron1': 8, 'neuron2': 4}
# 0.00038000238710083066,0.0005540019480234182 with: {'neuron1': 8, 'neuron2': 8}
# 0.00038000238710083066,0.0005540019480234182 with: {'neuron1': 16, 'neuron2': 2}
# 0.00038000238710083066,0.0005540019480234182 with: {'neuron1': 16, 'neuron2': 4}
# 0.00038000238710083066,0.0005540019480234182 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# # Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score

# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 10,kernel_initializer = 'uniform',activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(Dense(12,input_dim = 10,kernel_initializer = 'uniform',activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'relu'))
    
    optimizer = RMSprop(learning_rate = 0.1) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'mean_squared_error',optimizer = optimizer,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# Out:
# <ipython-input-50-fde82b13e58c>:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# %%
model.fit(x_train,y_train,batch_size = 100,epochs = 40)
y_pred =model.predict(x_train)

# %%
from sklearn.metrics import accuracy_score , mean_absolute_error , mean_squared_error

# %%
mean_absolute_error(y_train,y_pred)
# Out:
# 33.90214211076281

# %%
mean_squared_error(y_train ,y_pred)
# Out:
# 1400.4126835090726

# %%
y_test_pred = model.predict(x_test)

# %%
mean_absolute_error(y_test,y_test_pred)
# Out:
# 33.78995567375887

# %%
mean_squared_error(y_test ,y_test_pred)
# Out:
# 1391.1581578014188
